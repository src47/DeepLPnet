# %% [markdown]
# # Beamline 2-1 Samples

# %%
from src.helper_functions import * 
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ### Load in data from XY files

# %% [markdown]
# Here X is stored as a dictionary of dataframes corresponding to each XY file. Y comes from a csv which contain the true lattice parameters, crystal system and wavelength

# %%
X = np.load("data/Xdata.npy",allow_pickle=True).item()
Y = pd.read_csv("data/ssrl_labels.csv")

# %%
for i in range(len(Y)):
    row = Y.iloc[i,:]
    
    name = row['Material']
    wavelength = row['Wavelength']
    crystal_system = row['Crystal System']
    Xdata = X[name]
    y_true = np.sort(row[['a','b','c']])
    
    print("Analysing sample: {}, with crystal system: {} and wavelength: {}".format(name, crystal_system, wavelength))
    predictExptDataPipeline(Xdata, y_true, crystal_system=crystal_system, measured_wavelength=wavelength)
# Out:
# Analysing sample: BL21Robot_0001, with crystal system: cubic and wavelength: 0.7295684
#
# True LPs from Refined data:  [4.156826000000001 4.156826000000001 4.156826000000001]
#
# Predicted LPs using ML:  [[4.0949674 4.0949674 4.0949674]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0002, with crystal system: trigonal and wavelength: 0.7295684
#
# True LPs from Refined data:  [4.914155 4.914155 5.405698]
#
# Predicted LPs using ML:  [[4.630378  4.630378  7.4401126]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0096, with crystal system: orthorhombic and wavelength: 0.7295684
#
# True LPs from Refined data:  [7.6129809999999996 7.787221000000001 10.654601]
#
# Predicted LPs using ML:  [[ 6.842286   9.8295765 11.534866 ]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0105, with crystal system: hexagonal and wavelength: 0.7295684
#
# True LPs from Refined data:  [3.248316 3.248316 5.204098999999999]
#
# Predicted LPs using ML:  [[3.1493917 3.1493917 5.52836  ]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0106, with crystal system: cubic and wavelength: 0.7295684
#
# True LPs from Refined data:  [10.114644 10.114644 10.114644]
#
# Predicted LPs using ML:  [[10.117811 10.117811 10.117811]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0108, with crystal system: hexagonal and wavelength: 0.7295684
#
# True LPs from Refined data:  [5.032871 5.032871 13.741963]
#
# Predicted LPs using ML:  [[4.1460156 4.1460156 9.503    ]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0110, with crystal system: hexagonal and wavelength: 0.7295684
#
# True LPs from Refined data:  [4.986463 4.986463 17.060874]
#
# Predicted LPs using ML:  [[4.897682 4.897682 8.931528]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0112, with crystal system: monoclinic and wavelength: 0.7291367
#
# True LPs from Refined data:  [3.479887 8.055538 9.684352]
#
# Predicted LPs using ML:  [[5.435601 6.951897 9.457152]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0114, with crystal system: cubic and wavelength: 0.7291367
#
# True LPs from Refined data:  [5.6411 5.6411 5.6411]
#
# Predicted LPs using ML:  [[4.987077 4.987077 4.987077]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0115, with crystal system: cubic and wavelength: 0.7291367
#
# True LPs from Refined data:  [6.293349 6.293349 6.293349]
#
# Predicted LPs using ML:  [[7.1125846 7.1125846 7.1125846]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0118, with crystal system: monoclinic and wavelength: 0.7291367
#
# True LPs from Refined data:  [5.950125 7.5348630000000005 21.599985999999998]
#
# Predicted LPs using ML:  [[ 6.4716005 10.20678   15.2700615]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0119, with crystal system: monoclinic and wavelength: 0.7291367
#
# True LPs from Refined data:  [6.074835 7.108424 9.861905]
#
# Predicted LPs using ML:  [[4.8601837 6.5877314 7.569767 ]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: JK21_scraped, with crystal system: orthorhombic and wavelength: 0.9913
#
# True LPs from Refined data:  [4.64465 15.429591 19.288047]
#
# Predicted LPs using ML:  [[ 7.397295 14.795606 23.162544]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0116, with crystal system: monoclinic and wavelength: 0.7291367
#
# True LPs from Refined data:  [3.7130589999999994 5.62993 15.179421]
#
# Predicted LPs using ML:  [[ 4.7046614  9.633297  16.136042 ]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
#
# Analysing sample: BL21Robot_0101, with crystal system: cubic and wavelength: 0.7295684
#
# True LPs from Refined data:  [3.565629 3.565629 3.565629]
#
# Predicted LPs using ML:  [[2.7741554 2.7741554 2.7741554]]
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
